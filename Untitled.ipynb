# %%
import pandas as pd
import json

def read_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
        return data

def get_new_df(df, map_table):
    # 使用map_table的key新建一个DataFrame
    new_df = pd.DataFrame(columns=map_table.keys())

    # 创建行数与df相同的DataFrame, 使用maptable的value取df的一列，填充到new_df中
    for key, value in map_table.items():
        if value != '':
            new_df[key] = df[value]
    return new_df

def read_excel(file_path, begin=0, json_map_file=None):
    print("read excel file: ", file_path)

    df = pd.read_excel(file_path, header=begin)
    map_table = None if json_map_file is None else read_json(json_map_file)

    print(df.columns)
    print("map_table: ", map_table)

    print(df.shape)

    # 根据第一列的值进行分组
    grouped = df.groupby(df.columns[0])
    print("group size: ", len(grouped))
    
    new_df = get_new_df(df, map_table)
    print(new_df.head())

    print("\n")
    return df, new_df

# %%
RAW_DIR = r'D:\dev\R'

# HZ
file_path1 = RAW_DIR + r'\HZ\rawdata\事件查询-产犊.xlsx'
file_path2 = RAW_DIR + r'\HZ\rawdata\事件查询-配种.xlsx'

# FJ
file_path3 = RAW_DIR + r'\FJ\rawdata\产犊记录.xlsx'
file_path4 = RAW_DIR + r'\FJ\rawdata\流产记录.xlsx'
file_path5 = RAW_DIR + r'\FJ\rawdata\配种记录.xlsx'
file_path6 = RAW_DIR + r'\FJ\rawdata\事件明细5.14.xlsx'
file_path7 = RAW_DIR + r'\FJ\rawdata\孕检记录.xlsx'

d1, new_df1 = read_excel(file_path1,3, "maptable1.json")
d2, new_df2 = read_excel(file_path2,3, "maptable2.json")

d3, new_df3 = read_excel(file_path3,0, "maptable3.json")
d4, new_df4 = read_excel(file_path4,0, "maptable4.json")
d5, new_df5 = read_excel(file_path5,0, "maptable5.json")
d6, new_df6 = read_excel(file_path6,0, "maptable6.json")
d7, new_df7 = read_excel(file_path7,0, "maptable7.json")

print(new_df1.shape)
print(new_df2.shape)
print(new_df3.shape)
print(new_df4.shape)
print(new_df5.shape)
print(new_df6.shape)
print(new_df7.shape)

# 合并数据
merged_dfs = pd.concat([new_df1, new_df2, new_df3, new_df4, new_df5, new_df6, new_df7], axis=0)
print("merged_dfs shape:", merged_dfs.shape)
# Out:
# read excel file:  D:\dev\R\HZ\rawdata\事件查询-产犊.xlsx
# Index(['牛号', '注册号', '当前胎次', '事件胎次', '当前繁育状态', '牛只类别', '当前牛舍', '事件日期', '日龄',
#        '产犊牛舍', '产前牛只类别', '配种公牛号', '怀孕天数', '干奶天数', '围产天数', '干奶怀孕天数', '难易度评分',
#        '难产原因', '产犊数', '犊牛号', '工作人员', '犊牛状态', '犊牛性别', '出生重量', '犊牛备注', '上胎产犊日期',
#        '产犊间隔', '上胎怀孕日期', '理论产犊日期', '预产偏差天数', '上胎配种次数', '配种方式', '母牛父号', '分娩时间',
#        '母牛品种', '称重来源', '备注', '事件牧场', '当前牧场', '录入人员', '录入日期'],
#       dtype='object')
# map_table:  {'farm_id': '当前牧场', 'cow_id': '牛号', 'birth_date': '', 'parity': '事件胎次', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '配种公牛号', 'breeder': '工作人员', 'calving_date': '事件日期', 'breed_age': '日龄', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': '出生重量'}
# (9321, 41)
# group size:  6381
#   farm_id   cow_id birth_date  parity first_breed_date last_breed_date  \
# 0    洪泽牧场  T211292        NaN       1              NaN             NaN
# 1    洪泽牧场  T213012        NaN       1              NaN             NaN
# 2    洪泽牧场  T008968        NaN       2              NaN             NaN
# 3    洪泽牧场  T008968        NaN       1              NaN             NaN
# 4    洪泽牧场  A22A098        NaN       1              NaN             NaN
#
#     sire_code breeder calving_date  breed_age first_service_rate  \
# 0  029HO20658     杨国军   2023-10-23        752                NaN
# 1  629HO19770      张勇   2023-11-02        698                NaN
# 2  718HO00012     赵建波   2023-10-15       1051                NaN
# 3  629HO19093     赵建波   2022-11-02        704                NaN
# 4  629HO18999     万立国   2023-12-22        677                NaN
#
#   breed_interval service_count calving_age  gestation_length  \
# 0            NaN           NaN          NaN              NaN
# 1            NaN           NaN          NaN              NaN
# 2            NaN           NaN          NaN              NaN
# 3            NaN           NaN          NaN              NaN
# 4            NaN           NaN          NaN              NaN
#
#   post_calving_interval calving_interval  days_open calf_birth_weight
# 0                   NaN               NaN       NaN                33
# 1                   NaN               NaN       NaN                35
# 2                   NaN               NaN       NaN                42
# 3                   NaN               NaN       NaN                42
# 4                   NaN               NaN       NaN                37
#
#
# read excel file:  D:\dev\R\HZ\rawdata\事件查询-配种.xlsx
# Index(['牛号', '注册号', '当前胎次', '事件胎次', '当前繁育状态', '牛只类别', '当前牛舍', '事件日期', '日龄',
#        '泌乳天数', '产后天数', '配种牛舍', '配种公牛号', '冻精消耗', '配种方式', '配种结果', '配次', '上次配种日期',
#        '配前状态', '初检日期', '初检结果', '工作人员', '子宫评分', '子宫评分日期', '产犊日期', '公牛注册号',
#        '冻精类型', '备注', '事件牧场', '当前牧场', '录入人员', '录入日期'],
#       dtype='object')
# map_table:  {'farm_id': '当前牧场', 'cow_id': '牛号', 'birth_date': '', 'parity': '', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '配种公牛号', 'breeder': '', 'calving_date': '', 'breed_age': '日龄', 'first_service_rate': '', 'breed_interval': '', 'service_count': '配次', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (23451, 32)
# group size:  6519
#   farm_id   cow_id birth_date parity first_breed_date last_breed_date  \
# 0    洪泽牧场  T211292        NaN    NaN              NaN             NaN
# 1    洪泽牧场  T211292        NaN    NaN              NaN             NaN
# 2    洪泽牧场  T211292        NaN    NaN              NaN             NaN
# 3    洪泽牧场  T211292        NaN    NaN              NaN             NaN
# 4    洪泽牧场  T211292        NaN    NaN              NaN             NaN
#
#     sire_code breeder calving_date  breed_age first_service_rate  \
# 0  718HO00031     NaN          NaN        817                NaN
# 1  718HO00031     NaN          NaN        841                NaN
# 2  718HO00031     NaN          NaN        954                NaN
# 3  200HO12409     NaN          NaN        930                NaN
# 4  718HO00021     NaN          NaN        888                NaN
#
#   breed_interval  service_count calving_age  gestation_length  \
# 0            NaN              1          NaN              NaN
# 1            NaN              2          NaN              NaN
# 2            NaN              5          NaN              NaN
# 3            NaN              4          NaN              NaN
# 4            NaN              3          NaN              NaN
#
#   post_calving_interval calving_interval  days_open calf_birth_weight
# 0                   NaN               NaN       NaN               NaN
# 1                   NaN               NaN       NaN               NaN
# 2                   NaN               NaN       NaN               NaN
# 3                   NaN               NaN       NaN               NaN
# 4                   NaN               NaN       NaN               NaN
#
#
# read excel file:  D:\dev\R\FJ\rawdata\产犊记录.xlsx
# Index(['耳号', '牛舍', '事件日期', '事件', '事件类型', '技术员', '备注', '日龄', '月龄', '繁育状态',
#        '繁育状态2', '胎次', '本胎次发生次数', '事件时产后天数', '事件时泌乳天数', '创建人', '事件时牛只类别', '性别',
#        '离场日期', '当前牛舍', '创建日期', '所在牧场', '配种日期', '流产日期', '产犊日期', '干奶日期', '禁配日期',
#        '生日', '事件时配后天数', '事件时空怀天数', '事件时怀孕天数', '事件时干奶状态', '上次事件日期', '事件时间',
#        '产犊数量', '产犊评分', '留养数量', '公犊数量', '母犊数量', '留养公犊数量', '留养母犊数量', '未留养数量',
#        '未留养公犊数量', '未留养母犊数量', '转入牛舍', '新电子耳标', '新计步器', '新电新项圈子耳标', '多胞胎',
#        '犊牛1耳号', '犊牛1性别', '犊牛1分娩状态', '犊牛1出生重', '犊牛1品种', '犊牛1备注', '犊牛2耳号',
#        '犊牛2性别', '犊牛2分娩状态', '犊牛2出生重', '犊牛2品种', '犊牛2备注', '犊牛3耳号', '犊牛3性别',
#        '犊牛3分娩状态', '犊牛3出生重', '犊牛3品种', '犊牛3备注'],
#       dtype='object')
# map_table:  {'farm_id': '', 'cow_id': '耳号', 'birth_date': '生日', 'parity': '', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '', 'breeder': '技术员', 'calving_date': '产犊日期', 'breed_age': '日龄', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (1782, 67)
# group size:  756
#   farm_id  cow_id  birth_date parity first_breed_date last_breed_date  \
# 0     NaN   19009  2019-01-11    NaN              NaN             NaN
# 1     NaN   19009  2019-01-11    NaN              NaN             NaN
# 2     NaN   19009  2019-01-11    NaN              NaN             NaN
# 3     NaN   19009  2019-01-11    NaN              NaN             NaN
# 4     NaN   19012  2019-01-13    NaN              NaN             NaN
#
#   sire_code breeder calving_date  breed_age first_service_rate breed_interval  \
# 0       NaN     王庆土   2023-12-04       1788                NaN            NaN
# 1       NaN     王玉贵   2022-10-17       1375                NaN            NaN
# 2       NaN     李书通   2021-10-17       1010                NaN            NaN
# 3       NaN       陈   2020-11-12        671                NaN            NaN
# 4       NaN     王玉贵   2023-12-16       1798                NaN            NaN
#
#   service_count calving_age  gestation_length post_calving_interval  \
# 0           NaN          NaN              NaN                   NaN
# 1           NaN          NaN              NaN                   NaN
# 2           NaN          NaN              NaN                   NaN
# 3           NaN          NaN              NaN                   NaN
# 4           NaN          NaN              NaN                   NaN
#
#   calving_interval  days_open calf_birth_weight
# 0               NaN       NaN               NaN
# 1               NaN       NaN               NaN
# 2               NaN       NaN               NaN
# 3               NaN       NaN               NaN
# 4               NaN       NaN               NaN
#
#
# read excel file:  D:\dev\R\FJ\rawdata\流产记录.xlsx
# Index(['耳号', '牛舍', '事件日期', '事件', '事件类型', '技术员', '备注', '日龄', '月龄', '繁育状态',
#        '繁育状态2', '胎次', '本胎次发生次数', '事件时产后天数', '事件时泌乳天数', '创建人', '事件时牛只类别', '性别',
#        '离场日期', '当前牛舍', '创建日期', '所在牧场', '配种日期', '流产日期', '产犊日期', '干奶日期', '禁配日期',
#        '生日', '事件时配后天数', '事件时空怀天数', '事件时怀孕天数', '事件时干奶状态', '上次事件日期', '事件时间',
#        '流产原因', '揭发类型', '是否列胎次'],
#       dtype='object')
# map_table:  {'farm_id': '', 'cow_id': '耳号', 'birth_date': '', 'parity': '', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '', 'breeder': '', 'calving_date': '', 'breed_age': '', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (315, 37)
# group size:  229
#   farm_id  cow_id birth_date parity first_breed_date last_breed_date  \
# 0     NaN   21050        NaN    NaN              NaN             NaN
# 1     NaN    6213        NaN    NaN              NaN             NaN
# 2     NaN   22513        NaN    NaN              NaN             NaN
# 3     NaN   19178        NaN    NaN              NaN             NaN
# 4     NaN   21004        NaN    NaN              NaN             NaN
#
#   sire_code breeder calving_date breed_age first_service_rate breed_interval  \
# 0       NaN     NaN          NaN       NaN                NaN            NaN
# 1       NaN     NaN          NaN       NaN                NaN            NaN
# 2       NaN     NaN          NaN       NaN                NaN            NaN
# 3       NaN     NaN          NaN       NaN                NaN            NaN
# 4       NaN     NaN          NaN       NaN                NaN            NaN
#
#   service_count calving_age  gestation_length post_calving_interval  \
# 0           NaN          NaN              NaN                   NaN
# 1           NaN          NaN              NaN                   NaN
# 2           NaN          NaN              NaN                   NaN
# 3           NaN          NaN              NaN                   NaN
# 4           NaN          NaN              NaN                   NaN
#
#   calving_interval  days_open calf_birth_weight
# 0               NaN       NaN               NaN
# 1               NaN       NaN               NaN
# 2               NaN       NaN               NaN
# 3               NaN       NaN               NaN
# 4               NaN       NaN               NaN
#
#
# read excel file:  D:\dev\R\FJ\rawdata\配种记录.xlsx
# Index(['耳号', '牛舍', '事件日期', '事件', '事件类型', '技术员', '备注', '日龄', '月龄', '繁育状态',
#        '繁育状态2', '胎次', '本胎次发生次数', '事件时产后天数', '事件时泌乳天数', '创建人', '事件时牛只类别', '性别',
#        '离场日期', '当前牛舍', '创建日期', '所在牧场', '配种日期', '流产日期', '产犊日期', '干奶日期', '禁配日期',
#        '生日', '事件时配后天数', '事件时空怀天数', '事件时怀孕天数', '事件时干奶状态', '上次事件日期', '事件时间',
#        '冻精号', '胚胎号', '冻精号bak', '配种类型', '配种子类型', '是否性控', '耗精支数', '发情揭发员',
#        '配种结果', '空怀类型'],
#       dtype='object')
# map_table:  {'farm_id': '', 'cow_id': '耳号', 'birth_date': '生日', 'parity': '', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '冻精号', 'breeder': '技术员', 'calving_date': '产犊日期', 'breed_age': '日龄', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (4973, 44)
# group size:  764
#   farm_id  cow_id  birth_date parity first_breed_date last_breed_date  \
# 0     NaN   19009  2019-01-11    NaN              NaN             NaN
# 1     NaN   19009  2019-01-11    NaN              NaN             NaN
# 2     NaN   19009  2019-01-11    NaN              NaN             NaN
# 3     NaN   19009  2019-01-11    NaN              NaN             NaN
# 4     NaN   19009  2019-01-11    NaN              NaN             NaN
#
#      sire_code breeder calving_date  breed_age first_service_rate  \
# 0  荷斯坦37303032     李书通   2023-12-04       1939                NaN
# 1  荷斯坦37303032     李书通   2023-12-04       1892                NaN
# 2   P29HO20515     李书通   2023-12-04       1855                NaN
# 3   P29H018775     李书通   2022-10-17       1508                NaN
# 4   551HO04317     李书通   2022-10-17       1484                NaN
#
#   breed_interval service_count calving_age  gestation_length  \
# 0            NaN           NaN          NaN              NaN
# 1            NaN           NaN          NaN              NaN
# 2            NaN           NaN          NaN              NaN
# 3            NaN           NaN          NaN              NaN
# 4            NaN           NaN          NaN              NaN
#
#   post_calving_interval calving_interval  days_open calf_birth_weight
# 0                   NaN               NaN       NaN               NaN
# 1                   NaN               NaN       NaN               NaN
# 2                   NaN               NaN       NaN               NaN
# 3                   NaN               NaN       NaN               NaN
# 4                   NaN               NaN       NaN               NaN
#
#
# read excel file:  D:\dev\R\FJ\rawdata\事件明细5.14.xlsx
# Index(['耳号', '牛舍', '事件日期', '事件', '事件类型', '技术员', '备注', '日龄', '月龄', '繁育状态',
#        '繁育状态2', '胎次', '本胎次发生次数', '事件时产后天数', '事件时泌乳天数', '创建人', '事件时牛只类别', '性别',
#        '离场日期', '当前牛舍', '创建日期', '所在牧场', '配种日期', '流产日期', '产犊日期', '干奶日期', '禁配日期',
#        '生日', '事件时配后天数', '事件时空怀天数', '事件时怀孕天数', '事件时干奶状态', '上次事件日期', '事件时间',
#        '冻精号', '胚胎号', '冻精号bak', '配种类型', '配种子类型', '是否性控', '耗精支数', '发情揭发员',
#        '配种结果', '空怀类型'],
#       dtype='object')
# map_table:  {'farm_id': '', 'cow_id': '耳号', 'birth_date': '生日', 'parity': '胎次', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '冻精号', 'breeder': '技术员', 'calving_date': '', 'breed_age': '', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (4973, 44)
# group size:  764
#   farm_id  cow_id  birth_date  parity first_breed_date last_breed_date  \
# 0     NaN   19009  2019-01-11       4              NaN             NaN
# 1     NaN   19009  2019-01-11       4              NaN             NaN
# 2     NaN   19009  2019-01-11       4              NaN             NaN
# 3     NaN   19009  2019-01-11       3              NaN             NaN
# 4     NaN   19009  2019-01-11       3              NaN             NaN
#
#      sire_code breeder calving_date breed_age first_service_rate  \
# 0  荷斯坦37303032     李书通          NaN       NaN                NaN
# 1  荷斯坦37303032     李书通          NaN       NaN                NaN
# 2   P29HO20515     李书通          NaN       NaN                NaN
# 3   P29H018775     李书通          NaN       NaN                NaN
# 4   551HO04317     李书通          NaN       NaN                NaN
#
#   breed_interval service_count calving_age  gestation_length  \
# 0            NaN           NaN          NaN              NaN
# 1            NaN           NaN          NaN              NaN
# 2            NaN           NaN          NaN              NaN
# 3            NaN           NaN          NaN              NaN
# 4            NaN           NaN          NaN              NaN
#
#   post_calving_interval calving_interval  days_open calf_birth_weight
# 0                   NaN               NaN       NaN               NaN
# 1                   NaN               NaN       NaN               NaN
# 2                   NaN               NaN       NaN               NaN
# 3                   NaN               NaN       NaN               NaN
# 4                   NaN               NaN       NaN               NaN
#
#
# read excel file:  D:\dev\R\FJ\rawdata\孕检记录.xlsx
# Index(['耳号', '牛舍', '事件日期', '事件', '事件类型', '技术员', '备注', '日龄', '月龄', '繁育状态',
#        '繁育状态2', '胎次', '本胎次发生次数', '事件时产后天数', '事件时泌乳天数', '创建人', '事件时牛只类别', '性别',
#        '离场日期', '当前牛舍', '创建日期', '所在牧场', '配种日期', '流产日期', '产犊日期', '干奶日期', '禁配日期',
#        '生日', '事件时配后天数', '事件时空怀天数', '事件时怀孕天数', '事件时干奶状态', '上次事件日期', '事件时间',
#        '孕检原因', '胎儿数量', '胎儿性别', '孕检内容', '孕检位置', '孕检方式'],
#       dtype='object')
# map_table:  {'farm_id': '', 'cow_id': '耳号', 'birth_date': '生日', 'parity': '胎次', 'first_breed_date': '', 'last_breed_date': '', 'sire_code': '', 'breeder': '技术员', 'calving_date': '', 'breed_age': '', 'first_service_rate': '', 'breed_interval': '', 'service_count': '', 'calving_age ': '', 'gestation_length': '', 'post_calving_interval': '', 'calving_interval ': '', 'days_open': '', 'calf_birth_weight': ''}
# (7571, 40)
# group size:  764
#   farm_id  cow_id  birth_date  parity first_breed_date last_breed_date  \
# 0     NaN    8438  2018-10-10       4              NaN             NaN
# 1     NaN    6046  2016-03-04       6              NaN             NaN
# 2     NaN   22516  2022-01-16       1              NaN             NaN
# 3     NaN   22510  2022-01-08       1              NaN             NaN
# 4     NaN   22508  2022-01-08       1              NaN             NaN
#
#   sire_code breeder calving_date breed_age first_service_rate breed_interval  \
# 0       NaN     李书通          NaN       NaN                NaN            NaN
# 1       NaN     李书通          NaN       NaN                NaN            NaN
# 2       NaN     李书通          NaN       NaN                NaN            NaN
# 3       NaN     李书通          NaN       NaN                NaN            NaN
# 4       NaN     李书通          NaN       NaN                NaN            NaN
#
#   service_count calving_age  gestation_length post_calving_interval  \
# 0           NaN          NaN              NaN                   NaN
# 1           NaN          NaN              NaN                   NaN
# 2           NaN          NaN              NaN                   NaN
# 3           NaN          NaN              NaN                   NaN
# 4           NaN          NaN              NaN                   NaN
#
#   calving_interval  days_open calf_birth_weight
# 0               NaN       NaN               NaN
# 1               NaN       NaN               NaN
# 2               NaN       NaN               NaN
# 3               NaN       NaN               NaN
# 4               NaN       NaN               NaN
#
#
# (9321, 19)
# (23451, 19)
# (1782, 19)
# (315, 19)
# (4973, 19)
# (4973, 19)
# (7571, 19)
# merged_dfs shape: (52386, 19)
